# %% [markdown]
# # Naolib API Data Collector
#
# This notebook collects data from the Naolib API (Nantes public transportation) and sends it to Kafka for further processing. We'll focus on collecting real-time waiting times for various stops in Nantes.

# %%
import requests
from kafka import KafkaProducer
import json
import time
from datetime import datetime

# %% [markdown]
# ## Configure Kafka Producer
#
# First, let's set up our Kafka producer to send the data we collect:

# %%
kafka_config = {
        'bootstrap_servers': 'kafka1:9092',  # Update with your Kafka broker
    }

    # Initialize Kafka Producer
producer = KafkaProducer(
        bootstrap_servers=kafka_config['bootstrap_servers'],
        value_serializer=lambda v: json.dumps(v).encode('utf-8')
    )
# Out:
# ---------------------------------------------------------------------------
# NoBrokersAvailable                        Traceback (most recent call last)
# Cell In[5], line 5
#       1 kafka_config = {
#       2     'bootstrap_servers': 'localhost:9092',  # Essaye localhost au lieu de kafka
#       3 }
# ----> 5 producer = KafkaProducer(
#       6     bootstrap_servers=kafka_config['bootstrap_servers'],
#       7     value_serializer=lambda v: json.dumps(v).encode('utf-8')
#       8 )
#
# File /opt/conda/lib/python3.12/site-packages/kafka/producer/kafka.py:406, in KafkaProducer.__init__(self, **configs)
#     403 reporters = [reporter() for reporter in self.config['metric_reporters']]
#     404 self._metrics = Metrics(metric_config, reporters)
# --> 406 client = self.config['kafka_client'](
#     407     metrics=self._metrics, metric_group_prefix='producer',
#     408     wakeup_timeout_ms=self.config['max_block_ms'],
#     409     **self.config)
#     411 # Get auto-discovered / normalized version from client
#     412 self.config['api_version'] = client.config['api_version']
#
# File /opt/conda/lib/python3.12/site-packages/kafka/client_async.py:262, in KafkaClient.__init__(self, **configs)
#     260 # Check Broker Version if not set explicitly
#     261 if self.config['api_version'] is None:
# --> 262     self.config['api_version'] = self.check_version()
#     263 elif self.config['api_version'] in BROKER_API_VERSIONS:
#     264     self._api_versions = BROKER_API_VERSIONS[self.config['api_version']]
#
# File /opt/conda/lib/python3.12/site-packages/kafka/client_async.py:1064, in KafkaClient.check_version(self, node_id, timeout, **kwargs)
#    1062     raise Errors.NodeNotReadyError(node_id)
#    1063 else:
# -> 1064     raise Errors.NoBrokersAvailable()
#
# NoBrokersAvailable: NoBrokersAvailable

# %% [markdown]
# ## Define Key Stops
#
# Let's define a list of important stops in Nantes for our analysis:

# %%
# Define key stops (code, name)
key_stops = [
    ("COMM", "Commerce"),         # Central hub
    ("CTRE", "Chantrerie-Grandes Ecoles"),  # University area
    ("CRQU", "Place du Cirque"),  # City center
    ("HDMN", "Haluchère"),        # Connection to tram line
    ("GSEV", "Gare SNCF Sud")     # Main train station
]

# %% [markdown]
# ## Define Data Collection Function
#
# Create a function to collect data from the API and send it to Kafka:

# %%
def collect_and_send_to_kafka(stop_code, stop_name, topic_name="naolib_realtime"):
    """
    Collect waiting time data from Naolib API for a specific stop and send it to Kafka
    """
    # API URL - Get waiting times for the stop with up to 20 arrivals
    url = f"https://open.tan.fr/ewp/tempsattentelieu.json/{stop_code}/20"
    
    try:
        # Request data from API
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            # Add metadata
            timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            enriched_data = {
                "timestamp": timestamp,
                "stop_code": stop_code,
                "stop_name": stop_name,
                "arrivals": data
            }
            
            # Send to Kafka
            producer.send(topic_name, value=enriched_data)
            producer.flush()
            
            print(f"Data for {stop_name} ({stop_code}) sent to Kafka topic '{topic_name}'")
            return True
        else:
            print(f"Failed to fetch data for {stop_name} ({stop_code}): HTTP {response.status_code}")
            return False
    except Exception as e:
        print(f"Error collecting data for {stop_name} ({stop_code}): {str(e)}")
        return False

# %% [markdown]
# ## Manual Test for a Single Stop
#
# Let's test our function with a single stop:

# %%
# Test with Commerce stop
test_stop_code, test_stop_name = key_stops[0]
success = collect_and_send_to_kafka(test_stop_code, test_stop_name)

if success:
    print("Test successful!")
else:
    print("Test failed!")
# Out:
# Data for Commerce (COMM) sent to Kafka topic 'naolib_realtime'
# Test successful!

# %% [markdown]
# ## Continuous Data Collection Loop
#
# Now, let's set up a loop to continuously collect data from all our key stops:

# %%
# Run for a specific duration (in minutes) or until interrupted
duration_minutes = 60  # Change this as needed
interval_seconds = 30  # Time between API calls for each stop

start_time = datetime.now()
end_time = start_time.timestamp() + (duration_minutes * 60)

try:
    while datetime.now().timestamp() < end_time:
        # Collect data for each stop
        for stop_code, stop_name in key_stops:
            collect_and_send_to_kafka(stop_code, stop_name)
            time.sleep(2)  # Brief pause between stops to avoid API rate limits
        
        # Wait for the next collection cycle
        print(f"Completed collection cycle at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"Waiting {interval_seconds} seconds for next cycle...")
        time.sleep(interval_seconds)
        
except KeyboardInterrupt:
    print("Data collection interrupted by user.")
finally:
    print("Closing Kafka producer...")
    producer.close()
    print("Data collection complete.")
# Out:
# Data for Commerce (COMM) sent to Kafka topic 'naolib_realtime'
# Data for Chantrerie-Grandes Ecoles (CTRE) sent to Kafka topic 'naolib_realtime'
# Data for Place du Cirque (CRQU) sent to Kafka topic 'naolib_realtime'
# Data for Haluchère (HDMN) sent to Kafka topic 'naolib_realtime'
# Data for Gare SNCF Sud (GSEV) sent to Kafka topic 'naolib_realtime'
# Completed collection cycle at 2025-03-25 00:02:04
# Waiting 30 seconds for next cycle...
# Data collection interrupted by user.
# Closing Kafka producer...
# Data collection complete.

# %% [markdown]
# ## Analyze Collected Data Structure
#
# Let's look at the structure of the data we're collecting:

# %%
# Fetch a sample of data to analyze its structure
sample_url = f"https://open.tan.fr/ewp/tempsattentelieu.json/COMM/5"
response = requests.get(sample_url)

if response.status_code == 200:
    data = response.json()
    
    # Print the JSON structure
    print(json.dumps(data, indent=2))
    
    # Print the important fields we'll use for analysis
    print("\nKey data points for analysis:")
    for item in data:
        line_num = item.get('ligne', {}).get('numLigne', 'Unknown')
        terminus = item.get('terminus', 'Unknown')
        wait_time = item.get('temps', 'Unknown')
        is_real_time = item.get('tempsReel', False)
        
        print(f"Line {line_num} to {terminus}: Wait time {wait_time} (Real-time: {is_real_time})")
else:
    print(f"Failed to fetch sample data: HTTP {response.status_code}")
# Out:
# [
#   {
#     "sens": 2,
#     "terminus": "Commerce",
#     "infotrafic": true,
#     "temps": "9mn",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "1",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COMC1"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Fran\u00e7ois Mitterrand",
#     "infotrafic": true,
#     "temps": "12mn",
#     "dernierDepart": "true",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "1",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COMB2"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "Commerce",
#     "infotrafic": true,
#     "temps": "36mn",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "1",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COMC1"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "Espace Diderot",
#     "infotrafic": false,
#     "temps": "8mn",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "2",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COME2"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Orvault Grand Val",
#     "infotrafic": false,
#     "temps": "10mn",
#     "dernierDepart": "true",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "2",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COME1"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "Espace Diderot",
#     "infotrafic": false,
#     "temps": "36mn",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "2",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COME2"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Marcel Paul",
#     "infotrafic": true,
#     "temps": "8mn",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "3",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COME1"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "Trocardi\u00e8re",
#     "infotrafic": true,
#     "temps": "9mn",
#     "dernierDepart": "true",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "3",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COME2"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Marcel Paul",
#     "infotrafic": true,
#     "temps": "43mn",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "3",
#       "typeLigne": 1
#     },
#     "arret": {
#       "codeArret": "COME1"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "Gare Sud",
#     "infotrafic": false,
#     "temps": "6mn",
#     "dernierDepart": "true",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "C2",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COME3"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Le Cardo",
#     "infotrafic": false,
#     "temps": "24mn",
#     "dernierDepart": "true",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "C2",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COMF1"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Armor",
#     "infotrafic": false,
#     "temps": "proche",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "C3",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COMF1"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "Bd de Doulon",
#     "infotrafic": false,
#     "temps": "24mn",
#     "dernierDepart": "true",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "C3",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COME3"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Armor",
#     "infotrafic": false,
#     "temps": "28mn",
#     "dernierDepart": "false",
#     "tempsReel": "true",
#     "ligne": {
#       "numLigne": "C3",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COMF1"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Joneli\u00e8re",
#     "infotrafic": true,
#     "temps": "",
#     "dernierDepart": "false",
#     "tempsReel": "false",
#     "ligne": {
#       "numLigne": "26",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COMF1"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "H\u00f4tel de R\u00e9gion",
#     "infotrafic": true,
#     "temps": "",
#     "dernierDepart": "false",
#     "tempsReel": "false",
#     "ligne": {
#       "numLigne": "26",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COME3"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Marcel Paul",
#     "infotrafic": true,
#     "temps": "",
#     "dernierDepart": "false",
#     "tempsReel": "false",
#     "ligne": {
#       "numLigne": "54",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COMF1"
#     }
#   },
#   {
#     "sens": 2,
#     "terminus": "Saupin",
#     "infotrafic": true,
#     "temps": "",
#     "dernierDepart": "false",
#     "tempsReel": "false",
#     "ligne": {
#       "numLigne": "54",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COME3"
#     }
#   },
#   {
#     "sens": 1,
#     "terminus": "Chantrerie - Grandes \u00c9coles",
#     "infotrafic": false,
#     "temps": "",
#     "dernierDepart": "false",
#     "tempsReel": "false",
#     "ligne": {
#       "numLigne": "NC",
#       "typeLigne": 3
#     },
#     "arret": {
#       "codeArret": "COMF1"
#     }
#   }
# ]
#
# Key data points for analysis:
# Line 1 to Commerce: Wait time 9mn (Real-time: true)
# Line 1 to François Mitterrand: Wait time 12mn (Real-time: true)
# Line 1 to Commerce: Wait time 36mn (Real-time: true)
# Line 2 to Espace Diderot: Wait time 8mn (Real-time: true)
# Line 2 to Orvault Grand Val: Wait time 10mn (Real-time: true)
# Line 2 to Espace Diderot: Wait time 36mn (Real-time: true)
# Line 3 to Marcel Paul: Wait time 8mn (Real-time: true)
# Line 3 to Trocardière: Wait time 9mn (Real-time: true)
# Line 3 to Marcel Paul: Wait time 43mn (Real-time: true)
# Line C2 to Gare Sud: Wait time 6mn (Real-time: true)
# Line C2 to Le Cardo: Wait time 24mn (Real-time: true)
# Line C3 to Armor: Wait time proche (Real-time: true)
# Line C3 to Bd de Doulon: Wait time 24mn (Real-time: true)
# Line C3 to Armor: Wait time 28mn (Real-time: true)
# Line 26 to Jonelière: Wait time  (Real-time: false)
# Line 26 to Hôtel de Région: Wait time  (Real-time: false)
# Line 54 to Marcel Paul: Wait time  (Real-time: false)
# Line 54 to Saupin: Wait time  (Real-time: false)
# Line NC to Chantrerie - Grandes Écoles: Wait time  (Real-time: false)
